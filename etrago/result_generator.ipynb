# %%
import etrago
# Out:
# c:\Users\Sayed Mohammad\.conda\envs\etrago\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
#   "class": algorithms.Blowfish,
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pyproj\crs\crs.py:141: FutureWarning:
#
# '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pyproj\crs\crs.py:141: FutureWarning:
#
# '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pyproj\crs\crs.py:141: FutureWarning:
#
# '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pyproj\crs\crs.py:141: FutureWarning:
#
# '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6

# %%
n = etrago.Etrago(
    csv_folder_name ="D:\eTraGo\etrago_old\etrago\Result_V0_8760",
    json_path = "D:\eTraGo\etrago_old\etrago\Result_V0_8760\args.json"
)
# Out:
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:120: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:146: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:146: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:146: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:146: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:146: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:146: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:146: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:146: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:146: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:146: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:146: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:146: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:146: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:146: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:146: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:146: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:146: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:146: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:146: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:146: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:146: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:146: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:146: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:146: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:146: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:146: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# INFO:pypsa.io:Imported network Result_V0_8760 has buses, carriers, generators, lines, links, loads, storage_units, stores
# C:\Users\Sayed Mohammad\AppData\Roaming\Python\Python311\site-packages\pypsa\io.py:137: DtypeWarning:
#
# Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#
# INFO:pypsa.io:Imported network clustering has buses, lines, links

# %%
n.network.links.to_csv('links.csv', index=False)

# %%
n.network.links
# Out:
#       scn_name bus0   bus1                   carrier        p_nom  \
# Link
# 0     eGon2035    0  43540                       dsm    96.308634
# 1     eGon2035    0  49990  central_resistive_heater     0.008769
# 2     eGon2035    0  50120  central_resistive_heater     0.034350
# 3     eGon2035    0  52075           rural_heat_pump   557.879161
# 4     eGon2035    0  70456               BEV_charger  1062.945431
# ...        ...  ...    ...                       ...          ...
# 3958  eGon2035    9  75054  central_resistive_heater     3.111428
# 3959  eGon2035    9  75104         central_heat_pump     0.676182
# 3960  eGon2035    9  75104  central_resistive_heater     0.577449
# 3961  eGon2035    9  75167         central_heat_pump     0.108070
# 3962  eGon2035    9  75167  central_resistive_heater     0.359760
#
#       p_nom_extendable  p_nom_max  capital_cost  length type  ...  \
# Link                                                          ...
# 0                False        inf           0.0     0.0       ...
# 1                False        inf           0.0     0.0       ...
# 2                False        inf           0.0     0.0       ...
# 3                False        inf           0.0     0.0       ...
# 4                False        inf           0.0     0.0       ...
# ...                ...        ...           ...     ...  ...  ...
# 3958             False        inf           0.0     0.0       ...
# 3959             False        inf           0.0     0.0       ...
# 3960             False        inf           0.0     0.0       ...
# 3961             False        inf           0.0     0.0       ...
# 3962             False        inf           0.0     0.0       ...
#
#       start_up_cost  shut_down_cost  ramp_limit_start_up  \
# Link
# 0               NaN             NaN                  NaN
# 1               NaN             NaN                  NaN
# 2               NaN             NaN                  NaN
# 3               NaN             NaN                  NaN
# 4               NaN             NaN                  NaN
# ...             ...             ...                  ...
# 3958            NaN             NaN                  NaN
# 3959            NaN             NaN                  NaN
# 3960            NaN             NaN                  NaN
# 3961            NaN             NaN                  NaN
# 3962            NaN             NaN                  NaN
#
#       ramp_limit_shut_down  p_set  p_max_pu  terrain_factor  committable  \
# Link
# 0                      NaN    0.0       1.0             1.0        False
# 1                      NaN    0.0       1.0             1.0        False
# 2                      NaN    0.0       1.0             1.0        False
# 3                      NaN    0.0       1.0             1.0        False
# 4                      NaN    0.0       1.0             1.0        False
# ...                    ...    ...       ...             ...          ...
# 3958                   NaN    0.0       1.0             1.0        False
# 3959                   NaN    0.0       1.0             1.0        False
# 3960                   NaN    0.0       1.0             1.0        False
# 3961                   NaN    0.0       1.0             1.0        False
# 3962                   NaN    0.0       1.0             1.0        False
#
#       ramp_limit_up  ramp_limit_down
# Link
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN
# ...             ...              ...
# 3958            NaN              NaN
# 3959            NaN              NaN
# 3960            NaN              NaN
# 3961            NaN              NaN
# 3962            NaN              NaN
#
# [3963 rows x 35 columns]

# %%
n.plot_carrier(carrier_links=["power_to_H2"])
# n.plot_clusters()
# n.plot_flexibility_usage(flexibility='dsm'/'BEV charger'/heat/battery/h2_store)
# n.plot_gas_generation() #this generate a liner graph to show production for specific period by GW
# n.plot_gas_summary()
# n.plot_grid(line_colors= 'expansion_abs/line_loading'/expansion_rel/v_nom)
# n.plot_h2_generation()
# n.plot_h2_summary()results300hours/
# n.plot_heat_loads()
# n.plot_heat_summary()
#n.plot_flexibility_usage()
# b.plot_gas_summary(t_resolution='300H', stacked=False, save_path=False )



# #below command lines are to find/work with time series data
# n.network.generators_t
# n.network.loads_t.p
# n.loads_t.p
# n.network.loads_t.p.iloc[1]
# n.network.loads_t.p.iloc[1]
# n.network.loads_t.p.iloc[:1]
# n.network.loads_t.p.iloc[:1].plot()
# n.network.loads_t.p.iloc[:1].T.plot()
# # compere the new version of plots with dev branch
# Out:
# c:\Users\Sayed Mohammad\.conda\envs\etrago\Lib\site-packages\cartopy\mpl\style.py:76: UserWarning:
#
# facecolor will have no effect as it has been defined as "never".
